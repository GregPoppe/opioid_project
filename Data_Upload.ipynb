# %%
#Import Libraries

import pandas as pd
import matplotlib as plt

# %%
#read data from folder

district_data = pd.read_csv("../uwi/data/districtdata.csv")
county_data = pd.read_csv("../uwi/data/countydata.csv")
state_data = pd.read_csv("../uwi/data/statedata.csv")
# Out:
# /Users/gregpoppe/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Check length of data sets to check for reasonableness

print(state_data.shape)
print(district_data.shape)
print(county_data.shape)
# Out:
# (16096, 7)
# (86376, 8)
# (974602, 9)

# %%
#Add a column for county and state to eliminate duplicate county names in multiple states

county_data['State_County'] = county_data['STATE'] + " - " + county_data['COUNTY']

# %%
# Out:
#         Unnamed: 0  STATEFP  COUNTYFP  YEAR   INDICATOR  VALUE        COUNTY  \
# 3477          3477       19         1  2015      MH_fac      1  Adair County
# 3543          3543       19         1  2015  Med_MH_fac      1  Adair County
# 3861          3861       21         1  2014      MH_fac      2  Adair County
# 3962          3962       21         1  2014  Med_MH_fac      2  Adair County
# 4063          4063       21         1  2015      MH_fac      2  Adair County
# 4169          4169       21         1  2015  Med_MH_fac      2  Adair County
# 5734          5734       29         1  2014      MH_fac      2  Adair County
# 5806          5806       29         1  2014  Med_MH_fac      2  Adair County
# 5877          5877       29         1  2015      MH_fac      2  Adair County
# 5950          5950       29         1  2015  Med_MH_fac      2  Adair County
# 7903          7903       40         1  2014      MH_fac      1  Adair County
# ...
